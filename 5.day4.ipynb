# %% [markdown]
# <a href="https://colab.research.google.com/github/minsoo3102/python_1/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 조건문 사용법 예제-1

# %%
name = "BlackMusk"
if name == "BlackMusk":
    print("이름이 맞습니다")
else:
    print("이름이 다릅니다")
# Out:
# 이름이 맞습니다

# %%
potket = 1000
if potket == 1000:
    print("복권 구매")
elif potket == 500:
    print("껌 구매")
else:
    print("집이나 가자")
# Out:
# 복권 구매

# %% [markdown]
# 조건문 사용 예제-2

# %%
a = "사과"
b = "바나나"
c = "치즈"
if a == "사과" or b == "안바나나":
    print("사과 이거나 바나나 입니다")
if a == "사과" and b =="바나나":
    print("사과 이고 바나나 입니다")
if not a =="사과":
    print("사과가 아니어야 여기 들어옵니다")
# Out:
# 사과 이거나 바나나 입니다
# 사과 이고 바나나 입니다

# %%
a = [1,2,3,4,5,6,7,8] #튜플
if 1 in a:
    print("a 리스트에 1이 포함되어있습니다")
elif 10 in a:
    print("a 리스트에 10이 포함 되어있습니다")

# %% [markdown]
# 조건문 사용 예제-3

# %%
p_class = "z"
sel_amount = 79900

if p_class == "A":
      sel_amount *= 0.7 # 5930.0
      print(f'판매가는 {sel_amount}원 입니다')
elif p_class == "B": # 67915.0
      sel_amount *= 0.85
      print(f'판매가는 {sel_amount}원 입니다')
elif p_class == "C": # 73508.0
      sel_amount *= 0.92
      print(f'판매가는 {sel_amount}원 입니다')
elif p_class == "Z": # 84900
      sel_amount += 5000
      print(f'판매가는 {sel_amount}원 입니다')

# %%
p_class = 'B'
sel_amount = 7900

if p_class == 'A':
    sel_amount *= 0.7
    print(f'판매가는 {sel_amount}원입니다')
elif p_class == 'B':
    sel_amount *= 0.85
    print(f'판매가는 {sel_amount}원 입니다')
    print('판매가는 %d입니다' % sel_amount)
# Out:
# 판매가는 6715.0원 입니다
# 판매가는 6715입니다

# %% [markdown]
# 조건문 사용 예제-4

# %%
x =11

if x < 10:
    print('x는 10보다 작다')
else:
    print('x는 10보다 작지 않다')
# Out:
# x는 10보다 작지 않다

# %%
x = 2

if x%2 == 0:
    print('x는 짝수다')
else:
    print('x는 홀수다')
# Out:
# x는 짝수다

# %% [markdown]
# 조건문 사용 예제-5

# %%
x = 3

if x < 10:
    print('x는 10보다 작다')
    if x%2 == 0:
        print('x는 짝수다')
    else:
        print('x는 홀수다')
else:
    print('x는 10보다 크다')
    if x%2 == 0:
        print('x는 짝수다')
    else:
        print('x는 홀수다')
# Out:
# x는 10보다 작다
# x는 홀수다

# %% [markdown]
# 조건문 사용-while

# %%
treeHit = 0

while treeHit < 10:
     treeHit = treeHit +1
     print("나무를 %d번 찍었습니다" % treeHit)
    if treeHit == 10:
         print("나무 넘어갑니다")
# Out:
# 나무를 1번 찍었습니다
# 나무를 2번 찍었습니다
# 나무를 3번 찍었습니다
# 나무를 4번 찍었습니다
# 나무를 5번 찍었습니다
# 나무를 6번 찍었습니다
# 나무를 7번 찍었습니다
# 나무를 8번 찍었습니다
# 나무를 9번 찍었습니다
# 나무를 10번 찍었습니다
# 나무 넘어갑니다

# %% [markdown]
# 조건문 사용-break

# %%
coffee = 10
money = 300

while money:
    print("돈을 받았으니 커피를 줍니다")
    coffee = coffee -1
    print("남은 커피의 양은 %d개입니다"% coffee)
    if coffee == 0:
        print("커피가 다 떨어졌습니다. 판매를 중지합니다")
        break
# Out:
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 9개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 8개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 7개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 6개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 5개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 4개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 3개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 2개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 1개입니다
# 돈을 받았으니 커피를 줍니다
# 남은 커피의 양은 0개입니다
# 커피가 다 떨어졌습니다. 판매를 중지합니다

# %% [markdown]
# 조건문 사용-while 무한루프

# %%
while True:
    print("Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# Ctrl+C를 눌러야 while문을 빠져나갈 수 있습니다
# ...

# %% [markdown]
# 조건문 사용-while 예제

# %%
i = 0
result1 = 0
while i < 100:
    i = i + 1
    if i % 2 == 0:
        print('1번 방법 : {0} {1}'.format(i,result1))
        result1 = result1 + i

print('1번 방법 : {0}'.format(result1))
# Out:
# 1번 방법 : 2 0
# 1번 방법 : 4 2
# 1번 방법 : 6 6
# 1번 방법 : 8 12
# 1번 방법 : 10 20
# 1번 방법 : 12 30
# 1번 방법 : 14 42
# 1번 방법 : 16 56
# 1번 방법 : 18 72
# 1번 방법 : 20 90
# 1번 방법 : 22 110
# 1번 방법 : 24 132
# 1번 방법 : 26 156
# 1번 방법 : 28 182
# 1번 방법 : 30 210
# 1번 방법 : 32 240
# 1번 방법 : 34 272
# 1번 방법 : 36 306
# 1번 방법 : 38 342
# 1번 방법 : 40 380
# 1번 방법 : 42 420
# 1번 방법 : 44 462
# 1번 방법 : 46 506
# 1번 방법 : 48 552
# 1번 방법 : 50 600
# 1번 방법 : 52 650
# 1번 방법 : 54 702
# 1번 방법 : 56 756
# 1번 방법 : 58 812
# 1번 방법 : 60 870
# 1번 방법 : 62 930
# 1번 방법 : 64 992
# 1번 방법 : 66 1056
# 1번 방법 : 68 1122
# 1번 방법 : 70 1190
# 1번 방법 : 72 1260
# 1번 방법 : 74 1332
# 1번 방법 : 76 1406
# 1번 방법 : 78 1482
# 1번 방법 : 80 1560
# 1번 방법 : 82 1640
# 1번 방법 : 84 1722
# 1번 방법 : 86 1806
# 1번 방법 : 88 1892
# 1번 방법 : 90 1980
# 1번 방법 : 92 2070
# 1번 방법 : 94 2162
# 1번 방법 : 96 2256
# 1번 방법 : 98 2352
# 1번 방법 : 100 2450
# 1번 방법 : 2550

# %%
j = 0
result2 = 0
while True:
    if j > 100:
        break

    j = j + 1
    if j %  2 == 0:
        result2 = result2 + j

print('2번 방법 (break): {0}'.format(result2))
# Out:
# 2번 방법 (break): 2550

# %%
k = 0
result3 = 0
while k < 100:
    k = k+1
    if k % 2 ! = 0:
      continue
    result3 = result3 + k

print('3번 방법 (continue): {0}'.format(result3))
# Out:
#   File "<ipython-input-48-f0a58c28f20b>", line 5
#     if k % 2 ! = 0:
#              ^
# SyntaxError: invalid syntax
